# %%
pip install matplotlib
# Out:
# ...
#
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=[1,8,3]
y=[4,5,9]

# %%
plt.plot(x,y)
plt.grid()
plt.show()

# %%
data={
    "Salary":[25000,32400,56556,67876,67888,87777,10299,99483,88733,39894,28934,23894,23423,23423,23543,88775,34345,33213,94849,77464]}

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#    Salary
# 0   25000
# 1   32400
# 2   56556
# 3   67876
# 4   67888

# %%
df.shape
# Out:
# (20, 1)

# %%
plt.plot(df["Salary"])

# %%
plt.plot(df["Salary"],color="blue",marker="*",linestyle=":",linewidth=1)
plt.grid()
plt.show()

# %%
plt.hist(df["Salary"])
plt.show()

# %%
plt.hist(df["Salary"],bins=5)
plt.show()

# %%
plt.boxplot(df["Salary"])
plt.show()

# %%
df.loc[20]=0, inplace="True"
# Out:
#   Cell In[35], line 1
#     df.loc[20]=0, inplace="True"
#     ^
# SyntaxError: cannot assign to subscript here. Maybe you meant '==' instead of '='?

# %%
df

# %% [markdown]
# ##### plt.boxplot(df["Salary"])

# %%
df
# Out:
#     Salary
# 0    25000
# 1    32400
# 2    56556
# 3    67876
# 4    67888
# 5    87777
# 6    10299
# 7    99483
# 8    88733
# 9    39894
# 10   28934
# 11   23894
# 12   23423
# 13   23423
# 14   23543
# 15   88775
# 16   34345
# 17   33213
# 18   94849
# 19   77464

# %%
df.min()
# Out:
# Salary    10299
# dtype: int64

# %%
df.max()
# Out:
# Salary    99483
# dtype: int64

# %%
df.shape
# Out:
# (20, 1)

# %%
df.shape
# Out:
# (20, 1)

# %%
df["dept"]=["HR","IT","FINANCE","DATA"]*5

# %%
df.rename(columns={"dept":"Dept"},inplace=True)

# %%
df.head()
# Out:
#    Salary     Dept
# 0   25000       HR
# 1   32400       IT
# 2   56556  FINANCE
# 3   67876     DATA
# 4   67888       HR

# %%
count=df["Dept"].value_counts()
count
# Out:
# Dept
# HR         5
# IT         5
# FINANCE    5
# DATA       5
# Name: count, dtype: int64

# %%
plt.pie(count,labels=count.index)
plt.show()

# %%
plt.pie(count,labels=count.index,autopct="%1.1f")
plt.show()

# %%
plt.bar(count.index,count,color=["blue","orange","green","red"])
plt.show()

# %%
df
# Out:
#     Salary     Dept
# 0    25000       HR
# 1    32400       IT
# 2    56556  FINANCE
# 3    67876     DATA
# 4    67888       HR
# 5    87777       IT
# 6    10299  FINANCE
# 7    99483     DATA
# 8    88733       HR
# 9    39894       IT
# 10   28934  FINANCE
# 11   23894     DATA
# 12   23423       HR
# 13   23423       IT
# 14   23543  FINANCE
# 15   88775     DATA
# 16   34345       HR
# 17   33213       IT
# 18   94849  FINANCE
# 19   77464     DATA

# %%
df["Age"]=[24,23,25,23,27,28,26,25,29,30,31,32,34,35,36,38,45,46,76,45]

# %%
df
# Out:
#     Salary     Dept  Age
# 0    25000       HR   24
# 1    32400       IT   23
# 2    56556  FINANCE   25
# 3    67876     DATA   23
# 4    67888       HR   27
# 5    87777       IT   28
# 6    10299  FINANCE   26
# 7    99483     DATA   25
# 8    88733       HR   29
# 9    39894       IT   30
# 10   28934  FINANCE   31
# 11   23894     DATA   32
# 12   23423       HR   34
# 13   23423       IT   35
# 14   23543  FINANCE   36
# 15   88775     DATA   38
# 16   34345       HR   45
# 17   33213       IT   46
# 18   94849  FINANCE   76
# 19   77464     DATA   45

# %%
plt.scatter(df["Salary"],df["Age"],color="blue")
plt.show()

# %%
Sort_age=df.sort_values("Age")

# %%
df
# Out:
#     Salary     Dept  Age
# 0    25000       HR   24
# 1    32400       IT   23
# 2    56556  FINANCE   25
# 3    67876     DATA   23
# 4    67888       HR   27
# 5    87777       IT   28
# 6    10299  FINANCE   26
# 7    99483     DATA   25
# 8    88733       HR   29
# 9    39894       IT   30
# 10   28934  FINANCE   31
# 11   23894     DATA   32
# 12   23423       HR   34
# 13   23423       IT   35
# 14   23543  FINANCE   36
# 15   88775     DATA   38
# 16   34345       HR   45
# 17   33213       IT   46
# 18   94849  FINANCE   76
# 19   77464     DATA   45

# %%
plt.plot(Sort_age["Age"],df["Salary"])
plt.show()

# %%
plt.bar(Sort_age["Age"],df["Salary"],color="green")
plt.show()

# %%
hr_sal=df[df["Dept"]=="HR"]["Salary"]

# %%
print(hr_sal)
# Out:
# 0     25000
# 4     67888
# 8     88733
# 12    23423
# 16    34345
# Name: Salary, dtype: int64

# %%
it_sal=df[df["Dept"]=="IT"]["Salary"]

# %%
it_sal
# Out:
# 1     32400
# 5     87777
# 9     39894
# 13    23423
# 17    33213
# Name: Salary, dtype: int64

# %%
salary_by_dept=df.groupby("Dept")["Salary"].sum()

# %%
print(salaryby_dept)
# Out:
# Dept
# DATA       357492
# FINANCE    214181
# HR         239389
# IT         216707
# Name: Salary, dtype: int64

# %%
plt.pie(salary_by_dept,labels=salary_by_dept.index,autopct="%1.1f")
plt.savefig("Piechart.png")
plt.show()

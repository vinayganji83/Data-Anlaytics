# %%
import pandas as pd
import numpy as np

# %%
s=pd.Series([10,20,30,40,50])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s=pd.Series([10,20,30,40,50,'abc'])

# %%
s
# Out:
# 0     10
# 1     20
# 2     30
# 3     40
# 4     50
# 5    abc
# dtype: object

# %%
s.values
# Out:
# array([10, 20, 30, 40, 50, 'abc'], dtype=object)

# %%
s.name="numbers"

# %%
s
# Out:
# 0     10
# 1     20
# 2     30
# 3     40
# 4     50
# 5    abc
# Name: numbers, dtype: object

# %%
s[0]
# Out:
# 10

# %%
s[0:2]
# Out:
# 0    10
# 1    20
# Name: numbers, dtype: object

# %%
index=['apple','banana','strawberry','grapes','orange']

# %%
s
# Out:
# 0     10
# 1     20
# 2     30
# 3     40
# 4     50
# 5    abc
# Name: numbers, dtype: object

# %%
food_protein={
    "chicken":25.4,
    "mutton":22.5,
    "panner":20.7,
    "soya chunks":30
}

# %%
s2=pd.Series(food_protein,name="protein")

# %%
s2
# Out:
# chicken        25.4
# mutton         22.5
# panner         20.7
# soya chunks    30.0
# Name: protein, dtype: float64

# %%
df=s2.to_frame()

# %%
df
# Out:
#              protein
# chicken         25.4
# mutton          22.5
# panner          20.7
# soya chunks     30.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, chicken to soya chunks
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   protein  4 non-null      float64
# dtypes: float64(1)
# memory usage: 236.0+ bytes

# %%
s2>25
# Out:
# chicken         True
# mutton         False
# panner         False
# soya chunks     True
# Name: protein, dtype: bool

# %%
s2<30
# Out:
# chicken         True
# mutton          True
# panner          True
# soya chunks    False
# Name: protein, dtype: bool

# %%
print((s2>20) & (s2<25))
# Out:
# chicken        False
# mutton          True
# panner          True
# soya chunks    False
# Name: protein, dtype: bool

# %%
df
# Out:
#              protein
# chicken         25.4
# mutton          22.5
# panner          20.7
# soya chunks     30.0

# %%
df["mutton"] = 24

# %%
df
# Out:
#              protein  mutton
# chicken         25.4      24
# mutton          22.5      24
# panner          20.7      24
# soya chunks     30.0      24

# %%
s2
# Out:
# chicken        25.4
# mutton         22.5
# panner         20.7
# soya chunks    30.0
# Name: protein, dtype: float64

# %%
s2["mutton"]=24

# %%
s2
# Out:
# chicken        25.4
# mutton         24.0
# panner         20.7
# soya chunks    30.0
# Name: protein, dtype: float64

# %%
s2["mutton"]=22

# %%
s2
# Out:
# chicken        25.4
# mutton         22.0
# panner         20.7
# soya chunks    30.0
# Name: protein, dtype: float64

# %%
s2.drop("panner")
# Out:
# chicken        25.4
# mutton         22.0
# soya chunks    30.0
# Name: protein, dtype: float64

# %%
s2
# Out:
# chicken        25.4
# mutton         22.0
# panner         20.7
# soya chunks    30.0
# Name: protein, dtype: float64

# %%
s2.drop("soya chunks")
# Out:
# chicken    25.4
# mutton     22.0
# panner     20.7
# Name: protein, dtype: float64

# %%
s2
# Out:
# chicken        25.4
# mutton         22.0
# panner         20.7
# soya chunks    30.0
# Name: protein, dtype: float64

# %%
ser = pd.Series(['a', np.nan, 1, np.nan, 2])

print(ser.notnull().sum())
# Out:
# 3

# %%
import numpy as np

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000]
}

# %%
import pandas as pd

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
df.head()
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN

# %%
df.tail()
# Out:
#       Name   Age Department   Salary
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
df.head(3)
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0

# %%
df
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
df.iloc[1:3,:2]
# Out:
#       Name   Age
# 1      Bob  30.0
# 2  Charlie  35.0

# %%
df.loc[1:3,["Age","Department"]]
# Out:
#     Age Department
# 1  30.0         IT
# 2  35.0    Finance
# 3   NaN         IT

# %%
print(df[["Age","Department"]])
# Out:
#     Age Department
# 0  25.0         HR
# 1  30.0         IT
# 2  35.0    Finance
# 3   NaN         IT
# 4  29.0         HR
# 5  25.0         HR

# %%
df.drop("Age",axis=1)
# Out:
#       Name Department   Salary
# 0    Alice         HR  50000.0
# 1      Bob         IT  60000.0
# 2  Charlie    Finance  70000.0
# 3    David         IT  62000.0
# 4      Eve         HR      NaN
# 5    Alice         HR  50000.0

# %%
df
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
df.shape
# Out:
# (6, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        6 non-null      object
#  1   Age         5 non-null      float64
#  2   Department  6 non-null      object
#  3   Salary      5 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 324.0+ bytes

# %%
df.describe()
# Out:
#              Age        Salary
# count   5.000000      5.000000
# mean   28.800000  58400.000000
# std     4.147288   8532.291603
# min    25.000000  50000.000000
# 25%    25.000000  50000.000000
# 50%    29.000000  60000.000000
# 75%    30.000000  62000.000000
# max    35.000000  70000.000000

# %%
df["Salary"]=df["Salary"]-5000

# %%
df
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  45000.0
# 1      Bob  30.0         IT  55000.0
# 2  Charlie  35.0    Finance  65000.0
# 3    David   NaN         IT  57000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  45000.0

# %%
df.rename(columns={"Department": "Dept"}, inplace=True)

# %%
df
# Out:
#       Name   Age     Dept   Salary
# 0    Alice  25.0       HR  45000.0
# 1      Bob  30.0       IT  55000.0
# 2  Charlie  35.0  Finance  65000.0
# 3    David   NaN       IT  57000.0
# 4      Eve  29.0       HR      NaN
# 5    Alice  25.0       HR  45000.0

# %%
df["Dept"].unique()
# Out:
# array(['HR', 'IT', 'Finance'], dtype=object)

# %%
df["Salary"].unique()
# Out:
# array([45000., 55000., 65000., 57000.,    nan])

# %%
df["Age"].unique()
# Out:
# array([25., 30., 35., nan, 29.])

# %%
df["Dept"].value_counts()
# Out:
# Dept
# HR         3
# IT         2
# Finance    1
# Name: count, dtype: int64

# %%
df["Promoted_salary"]=df["Salary"]*10

# %%
df
# Out:
#       Name   Age     Dept   Salary  Promoted_salary
# 0    Alice  25.0       HR  45000.0         450000.0
# 1      Bob  30.0       IT  55000.0         550000.0
# 2  Charlie  35.0  Finance  65000.0         650000.0
# 3    David   NaN       IT  57000.0         570000.0
# 4      Eve  29.0       HR      NaN              NaN
# 5    Alice  25.0       HR  45000.0         450000.0

# %%
df.isnull().sum()
# Out:
# Name               0
# Age                1
# Dept               0
# Salary             1
# Promoted_salary    1
# dtype: int64

# %%
df.dropna()
# Out:
#       Name   Age     Dept   Salary  Promoted_salary
# 0    Alice  25.0       HR  45000.0         450000.0
# 1      Bob  30.0       IT  55000.0         550000.0
# 2  Charlie  35.0  Finance  65000.0         650000.0
# 5    Alice  25.0       HR  45000.0         450000.0

# %%
df
# Out:
#       Name   Age     Dept   Salary  Promoted_salary
# 0    Alice  25.0       HR  45000.0         450000.0
# 1      Bob  30.0       IT  55000.0         550000.0
# 2  Charlie  35.0  Finance  65000.0         650000.0
# 3    David   NaN       IT  57000.0         570000.0
# 4      Eve  29.0       HR      NaN              NaN
# 5    Alice  25.0       HR  45000.0         450000.0

# %%
df.dropna(how="any")
# Out:
#       Name   Age     Dept   Salary  Promoted_salary
# 0    Alice  25.0       HR  45000.0         450000.0
# 1      Bob  30.0       IT  55000.0         550000.0
# 2  Charlie  35.0  Finance  65000.0         650000.0
# 5    Alice  25.0       HR  45000.0         450000.0

# %%
df.dropna(how="all")
# Out:
#       Name   Age     Dept   Salary  Promoted_salary
# 0    Alice  25.0       HR  45000.0         450000.0
# 1      Bob  30.0       IT  55000.0         550000.0
# 2  Charlie  35.0  Finance  65000.0         650000.0
# 3    David   NaN       IT  57000.0         570000.0
# 4      Eve  29.0       HR      NaN              NaN
# 5    Alice  25.0       HR  45000.0         450000.0

# %%
df
# Out:
#       Name   Age     Dept   Salary  Promoted_salary
# 0    Alice  25.0       HR  45000.0         450000.0
# 1      Bob  30.0       IT  55000.0         550000.0
# 2  Charlie  35.0  Finance  65000.0         650000.0
# 3    David   NaN       IT  57000.0         570000.0
# 4      Eve  29.0       HR      NaN              NaN
# 5    Alice  25.0       HR  45000.0         450000.0

# %%
df.fillna(0)
# Out:
#       Name   Age     Dept   Salary  Promoted_salary
# 0    Alice  25.0       HR  45000.0         450000.0
# 1      Bob  30.0       IT  55000.0         550000.0
# 2  Charlie  35.0  Finance  65000.0         650000.0
# 3    David   0.0       IT  57000.0         570000.0
# 4      Eve  29.0       HR      0.0              0.0
# 5    Alice  25.0       HR  45000.0         450000.0

# %%
df['Age'].fillna(df['Age'].mean())
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3    28.8
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
df['Salary'].fillna(df["Salary"].median())
# Out:
# 0    45000.0
# 1    55000.0
# 2    65000.0
# 3    57000.0
# 4    55000.0
# 5    45000.0
# Name: Salary, dtype: float64

# %%
df
# Out:
#       Name   Age     Dept   Salary  Promoted_salary
# 0    Alice  25.0       HR  45000.0         450000.0
# 1      Bob  30.0       IT  55000.0         550000.0
# 2  Charlie  35.0  Finance  65000.0         650000.0
# 3    David   NaN       IT  57000.0         570000.0
# 4      Eve  29.0       HR      NaN              NaN
# 5    Alice  25.0       HR  45000.0         450000.0

# %%
df['Age'].fillna(method='ffill')
# Out:
# C:\Users\VEERENDRA\AppData\Local\Temp\ipykernel_18512\1265906299.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Age'].fillna(method='ffill')
# 0    25.0
# 1    30.0
# 2    35.0
# 3    35.0
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
df['Age'].fillna(method='bfill')
# Out:
# C:\Users\VEERENDRA\AppData\Local\Temp\ipykernel_18512\3224957626.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Age'].fillna(method='bfill')
# 0    25.0
# 1    30.0
# 2    35.0
# 3    29.0
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
df['Name'].replace("Charlie","Rose",inplace=True)
# Out:
# C:\Users\VEERENDRA\AppData\Local\Temp\ipykernel_18512\2612872993.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Name'].replace("Charlie","Rose",inplace=True)

# %%
df
# Out:
#     Name   Age     Dept   Salary  Promoted_salary
# 0  Alice  25.0       HR  45000.0         450000.0
# 1    Bob  30.0       IT  55000.0         550000.0
# 2   Rose  35.0  Finance  65000.0         650000.0
# 3  David   NaN       IT  57000.0         570000.0
# 4    Eve  29.0       HR      NaN              NaN
# 5  Alice  25.0       HR  45000.0         450000.0

# %%
df["Name"].replace("Rose", "Vinay", inplace=True)
# Out:
# C:\Users\VEERENDRA\AppData\Local\Temp\ipykernel_18512\2889432012.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Name"].replace("Rose", "Vinay", inplace=True)

# %%
df
# Out:
#     Name   Age     Dept   Salary  Promoted_salary
# 0  Alice  25.0       HR  45000.0         450000.0
# 1    Bob  30.0       IT  55000.0         550000.0
# 2  Vinay  35.0  Finance  65000.0         650000.0
# 3  David   NaN       IT  57000.0         570000.0
# 4    Eve  29.0       HR      NaN              NaN
# 5  Alice  25.0       HR  45000.0         450000.0

# %%
df["Age after 10years"]=df["Age"]+10

# %%
df
# Out:
#     Name   Age     Dept   Salary  Promoted_salary  Age after 10years
# 0  Alice  25.0       HR  45000.0         450000.0               35.0
# 1    Bob  30.0       IT  55000.0         550000.0               40.0
# 2  Vinay  35.0  Finance  65000.0         650000.0               45.0
# 3  David   NaN       IT  57000.0         570000.0                NaN
# 4    Eve  29.0       HR      NaN              NaN               39.0
# 5  Alice  25.0       HR  45000.0         450000.0               35.0

# %%
df.drop("Age after 10years",axis=1)
# Out:
#     Name   Age     Dept   Salary  Promoted_salary
# 0  Alice  25.0       HR  45000.0         450000.0
# 1    Bob  30.0       IT  55000.0         550000.0
# 2  Vinay  35.0  Finance  65000.0         650000.0
# 3  David   NaN       IT  57000.0         570000.0
# 4    Eve  29.0       HR      NaN              NaN
# 5  Alice  25.0       HR  45000.0         450000.0

# %%
df_dup=df[df.duplicated()]

# %%
df_dup
# Out:
#     Name   Age Dept   Salary  Promoted_salary  Age after 10years
# 5  Alice  25.0   HR  45000.0         450000.0               35.0

# %%
df_dup=df[df.duplicated(keep="first")]

# %%
df_dup
# Out:
#     Name   Age Dept   Salary  Promoted_salary  Age after 10years
# 5  Alice  25.0   HR  45000.0         450000.0               35.0

# %%
df_dup=df[df.duplicated(keep="last")]

# %%
df_dup
# Out:
#     Name   Age Dept   Salary  Promoted_salary  Age after 10years
# 0  Alice  25.0   HR  45000.0         450000.0               35.0

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#     Name   Age     Dept   Salary  Promoted_salary  Age after 10years
# 0  Alice  25.0       HR  45000.0         450000.0               35.0
# 1    Bob  30.0       IT  55000.0         550000.0               40.0
# 2  Vinay  35.0  Finance  65000.0         650000.0               45.0
# 3  David   NaN       IT  57000.0         570000.0                NaN
# 4    Eve  29.0       HR      NaN              NaN               39.0

# %%
df.drop("Age after 10years",axis=1,inplace=True)
# Out:
# C:\Users\VEERENDRA\AppData\Local\Temp\ipykernel_18512\106554741.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("Age after 10years",axis=1,inplace=True)

# %%
df
# Out:
#     Name   Age     Dept   Salary  Promoted_salary
# 0  Alice  25.0       HR  45000.0         450000.0
# 1    Bob  30.0       IT  55000.0         550000.0
# 2  Vinay  35.0  Finance  65000.0         650000.0
# 3  David   NaN       IT  57000.0         570000.0
# 4    Eve  29.0       HR      NaN              NaN

# %%
 df['Promoted_salary']=df['Promoted_salary'].apply(lambda x:x/10 if x>65000 else x)
# Out:
# C:\Users\VEERENDRA\AppData\Local\Temp\ipykernel_18512\771673374.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Promoted_salary']=df['Promoted_salary'].apply(lambda x:x/10 if x>65000 else x)

# %%
df
# Out:
#     Name   Age     Dept   Salary  Promoted_salary
# 0  Alice  25.0       HR  45000.0          45000.0
# 1    Bob  30.0       IT  55000.0          55000.0
# 2  Vinay  35.0  Finance  65000.0          65000.0
# 3  David   NaN       IT  57000.0          57000.0
# 4    Eve  29.0       HR      NaN              NaN

# %%
def multiply_age(x):
    return x*2
df['Age']=df['Age'].apply(multiply_age)
# Out:
# C:\Users\VEERENDRA\AppData\Local\Temp\ipykernel_18512\479766385.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age']=df['Age'].apply(multiply_age)

# %%
df
# Out:
#     Name   Age     Dept   Salary  Promoted_salary
# 0  Alice  50.0       HR  45000.0          45000.0
# 1    Bob  60.0       IT  55000.0          55000.0
# 2  Vinay  70.0  Finance  65000.0          65000.0
# 3  David   NaN       IT  57000.0          57000.0
# 4    Eve  58.0       HR      NaN              NaN

# %%
df['Age']=df['Age'].apply(lambda x:x/2)
# Out:
# C:\Users\VEERENDRA\AppData\Local\Temp\ipykernel_18512\1971227271.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age']=df['Age'].apply(lambda x:x/2)

# %%
df
# Out:
#     Name   Age     Dept   Salary  Promoted_salary
# 0  Alice  25.0       HR  45000.0          45000.0
# 1    Bob  30.0       IT  55000.0          55000.0
# 2  Vinay  35.0  Finance  65000.0          65000.0
# 3  David   NaN       IT  57000.0          57000.0
# 4    Eve  29.0       HR      NaN              NaN

# %%
data2={"Dept":["HR","IT","Finance"],"Location":["New york","San Franchise","Chicago"],"Manager":["Laura","Steve","Niha"]}

# %%
df2=pd.DataFrame(data2)

# %%
df
# Out:
#     Name   Age     Dept   Salary  Promoted_salary
# 0  Alice  25.0       HR  45000.0          45000.0
# 1    Bob  30.0       IT  55000.0          55000.0
# 2  Vinay  35.0  Finance  65000.0          65000.0
# 3  David   NaN       IT  57000.0          57000.0
# 4    Eve  29.0       HR      NaN              NaN

# %%
df2
# Out:
#       Dept       Location Manager
# 0       HR       New york   Laura
# 1       IT  San Franchise   Steve
# 2  Finance        Chicago    Niha

# %%
pd.concat([df,df2])
# Out:
#     Name   Age     Dept   Salary  Promoted_salary       Location Manager
# 0  Alice  25.0       HR  45000.0          45000.0            NaN     NaN
# 1    Bob  30.0       IT  55000.0          55000.0            NaN     NaN
# 2  Vinay  35.0  Finance  65000.0          65000.0            NaN     NaN
# 3  David   NaN       IT  57000.0          57000.0            NaN     NaN
# 4    Eve  29.0       HR      NaN              NaN            NaN     NaN
# 0    NaN   NaN       HR      NaN              NaN       New york   Laura
# 1    NaN   NaN       IT      NaN              NaN  San Franchise   Steve
# 2    NaN   NaN  Finance      NaN              NaN        Chicago    Niha

# %%
pd.concat([df,df2],axis=1)
# Out:
#     Name   Age     Dept   Salary  Promoted_salary     Dept       Location  \
# 0  Alice  25.0       HR  45000.0          45000.0       HR       New york
# 1    Bob  30.0       IT  55000.0          55000.0       IT  San Franchise
# 2  Vinay  35.0  Finance  65000.0          65000.0  Finance        Chicago
# 3  David   NaN       IT  57000.0          57000.0      NaN            NaN
# 4    Eve  29.0       HR      NaN              NaN      NaN            NaN
#
#   Manager
# 0   Laura
# 1   Steve
# 2    Niha
# 3     NaN
# 4     NaN

# %%
pd.merge(df,df2,on="Dept")
# Out:
#     Name   Age     Dept   Salary  Promoted_salary       Location Manager
# 0  Alice  25.0       HR  45000.0          45000.0       New york   Laura
# 1    Bob  30.0       IT  55000.0          55000.0  San Franchise   Steve
# 2  Vinay  35.0  Finance  65000.0          65000.0        Chicago    Niha
# 3  David   NaN       IT  57000.0          57000.0  San Franchise   Steve
# 4    Eve  29.0       HR      NaN              NaN       New york   Laura

# %%
data=pd.read_csv(r"C:\Users\VEERENDRA\Downloads\archive\data.csv")

# %%
data
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
data.shape
# Out:
# (4600, 18)

# %%
data.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
data["date"]=pd.to_datetime(data["date"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   datetime64[ns]
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...
